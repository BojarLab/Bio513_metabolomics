# %% [markdown]
# # Block 2: Univariate Analysis and PCA
#
# **Estimated time:** 4 hours
#
# **By the end of this block you should have:**
# - Run t-test and/or Mann-Whitney U test with FDR correction for each metabolite
# - Produced a volcano plot
# - Run PCA and interpreted the scores plot
# - Saved results for use in Block 3
#
# ---

# %% [markdown]
# ## 1. Setup

# %%
# !pip install pandas numpy matplotlib scipy scikit-learn -q

# %% [markdown]
# ### Load data from Block 1
#
# - **Google Colab:** Upload `processed_data.csv` and `transformed_unscaled_data.csv` from Block 1.
# - **Local Jupyter:** Files are loaded automatically from `results/`.

# %%
import sys, os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.stats import ttest_ind, mannwhitneyu
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

ON_COLAB = 'google.colab' in sys.modules
output_dir = Path("results")
output_dir.mkdir(exist_ok=True)

if ON_COLAB:
    from google.colab import files
    print("Upload processed_data.csv and transformed_unscaled_data.csv from Block 1:")
    uploaded = files.upload()
else:
    needed = ["results/processed_data.csv", "results/transformed_unscaled_data.csv"]
    missing = [f for f in needed if not os.path.exists(f)]
    print("ERROR: Missing:", missing) if missing else print("✓ Files found.")

# %%
# TO-DO: Load the two CSV files.
# Separate metadata (sample, group columns) from the feature matrices.

# TO-DO

# %% [markdown]
# ## 2. Univariate Analysis

# %%
# TO-DO: For each metabolite, run a t-test and/or Mann-Whitney U test
# comparing the two groups. Apply Benjamini-Hochberg FDR correction.
# Store results in a DataFrame with columns for p-value, FDR, and log2FC.
# Save to results/univariate_results.csv.

# TO-DO

# %% [markdown]
# ## 3. Volcano Plot

# %%
# TO-DO: Plot log2FC (x) vs -log10(FDR-adjusted p-value) (y).
# Mark significance thresholds. Label the top hits.
# Save the figure to results/volcano.png.

p_threshold  = 0.05
fc_threshold = 1.0

# TO-DO

# %% [markdown]
# ## 4. PCA

# %%
# TO-DO: Run PCA on the scaled matrix (rows = samples, columns = metabolites).
# Plot PC1 vs PC2 coloured by group. Label samples if helpful.
# Print the variance explained per component.
# Save scores and loadings to results/.

# TO-DO

# %% [markdown]
# ---
# ## What to bring to Block 3
#
# - `results/univariate_results.csv`
# - `results/volcano.png` and `results/pca_scores.png`
# - A note of 5–10 metabolites you find most interesting
