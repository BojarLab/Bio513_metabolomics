# %% [markdown]
# # Block 3: OPLS-DA and Visualisation
#
# **Estimated time:** 4 hours
#
# **By the end of this block you should have:**
# - Fitted an OPLS-DA model and validated it with cross-validation and permutation testing
# - Interpreted VIP scores and the S-plot
# - Produced boxplots and heatmaps for top metabolites
# - Generated a PDF report
# - Written a Results paragraph synthesising all three blocks
#
# ---

# %% [markdown]
# ## 1. Setup

# %%
# !pip install pandas numpy matplotlib scipy scikit-learn seaborn -q

# %% [markdown]
# ### Load data from Blocks 1 & 2
#
# - **Google Colab:** Upload `processed_data.csv`, `transformed_unscaled_data.csv`, and `univariate_results.csv`.
# - **Local Jupyter:** Files are loaded automatically.

# %%
import sys, os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

ON_COLAB = 'google.colab' in sys.modules
output_dir = Path("results")
output_dir.mkdir(exist_ok=True)
(output_dir / "boxplots").mkdir(exist_ok=True)

if ON_COLAB:
    from google.colab import files
    print("Upload: processed_data.csv, transformed_unscaled_data.csv, univariate_results.csv")
    uploaded = files.upload()
else:
    needed = ["results/processed_data.csv", "results/transformed_unscaled_data.csv",
              "results/univariate_results.csv"]
    missing = [f for f in needed if not os.path.exists(f)]
    print("ERROR: Missing:", missing) if missing else print("✓ Files found.")

# %%
# TO-DO: Load all three files and separate metadata from feature matrices.

# TO-DO

# %% [markdown]
# ## 2. OPLS-DA

# %%
# TO-DO: Fit an OPLS-DA model on the scaled matrix.
# Use 5-fold cross-validation. Report Q², accuracy, and AUC.
# See metabolomics_workflow_notebook.ipynb for a complete implementation.

# TO-DO

# %% [markdown]
# ## 3. Validate the Model

# %%
# TO-DO: Run a permutation test (200 permutations).
# Plot the distribution of permuted Q² values vs the observed Q².
# Report the permutation p-value.

# TO-DO

# %% [markdown]
# ## 4. VIP Scores and S-Plot

# %%
# TO-DO: Plot the top 30 VIP scores as a bar chart.
# Plot the S-plot (covariance vs correlation with the predictive score).
# Label the top metabolites on both plots.

# TO-DO

# %% [markdown]
# ## 5. Boxplots and Heatmap

# %%
# TO-DO: Plot boxplots for the top 12 metabolites by FDR from Block 2.
# Create a clustered heatmap of the top 30 most variable metabolites.

# TO-DO

# %% [markdown]
# ## 6. PDF Report

# %%
# TO-DO: Collect your key figures and save them to a PDF report.
# Save to results/metabolomics_report.pdf.
# Colab users: download the file.

from matplotlib.backends.backend_pdf import PdfPages

# TO-DO

# %% [markdown]
# ## 7. Results Paragraph
#
# Write a Results paragraph (6–10 sentences) integrating findings from all three blocks.
# Cover: number of significant metabolites, PCA separation, OPLS-DA performance (Q², AUC),
# top metabolites and their biological relevance, and how your findings compare with
# Mickiewicz *et al.*

# %%
results_paragraph = """
[Write your Results paragraph here]
"""
print(results_paragraph)

# %% [markdown]
# ---
# ## Bonus
#
# Re-run the analysis comparing **SIRS vs. Control** instead of Infection vs. Control.
# Do the same metabolites discriminate? How does model performance compare?
# What does this tell you about the specificity of the metabolic infection response?

# %%
# Bonus: SIRS vs Control
# TO-DO
